# %% [markdown]
# ## Sprint #1

# %%
# !pip install "git+https://github.com/bblais/Game" --upgrade
# Out:
# Collecting git+https://github.com/bblais/Game
#   Cloning https://github.com/bblais/Game to /Users/bblais/tmp/pip-req-build-m0m1l9v5
#   Running command git clone --filter=blob:none --quiet https://github.com/bblais/Game /Users/bblais/tmp/pip-req-build-m0m1l9v5
#   Resolved https://github.com/bblais/Game to commit aae5eb80be89f173183ab2ef1a9958c700d3077e
#   Preparing metadata (setup.py) ... done

# %%
import Game
# Out:
# Version:  0.3.01

# %% [markdown]
# If you happen the error "Cannot find command 'git'", then you need to install git.
#
# - open an anaconda prompt
# - type `conda install -c anaconda git`

# %% [markdown]
# if you get this error:

# %%
from game import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 from game import *
#
# ModuleNotFoundError: No module named 'game'

# %% [markdown]
# Remember that `Game` is different than `game`.

# %% [markdown]
# ## Sprint #2

# %% [markdown]
# Run this on the robot to update the software

# %%
pip install "git+https://github.com/bblais/Robot373" --upgrade

# %% [markdown]
# ## Sprint #3

# %% [markdown]
# - Windows comes with ssh
# - install Cyberduck for file transfer: https://cyberduck.io/

# %% [markdown]
# ## Sprint #4

# %%
# !pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in /Users/bblais/opt/anaconda3/lib/python3.9/site-packages (1.0.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/bblais/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: numpy>=1.14.6 in /Users/bblais/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (1.21.5)
# Requirement already satisfied: scipy>=1.1.0 in /Users/bblais/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in /Users/bblais/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn) (1.1.0)

# %%
# !pip install "git+https://github.com/bblais/classy" --upgrade
# Out:
# Collecting git+https://github.com/bblais/classy
#   Cloning https://github.com/bblais/classy to /Users/bblais/tmp/pip-req-build-_rc5rl9y
#   Running command git clone --filter=blob:none --quiet https://github.com/bblais/classy /Users/bblais/tmp/pip-req-build-_rc5rl9y
#   Resolved https://github.com/bblais/classy to commit f052cb1fd5646217074e77ef70658cdf5a7e01df
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /Users/bblais/venvs/work/lib/python3.12/site-packages (from classy==0.0.71) (2.4.4)
# Requirement already satisfied: scipy in /Users/bblais/venvs/work/lib/python3.12/site-packages (from classy==0.0.71) (1.17.1)
# Requirement already satisfied: Pillow in /Users/bblais/venvs/work/lib/python3.12/site-packages (from classy==0.0.71) (12.2.0)
# Requirement already satisfied: flax in /Users/bblais/venvs/work/lib/python3.12/site-packages (from classy==0.0.71) (0.12.0)
# Requirement already satisfied: jax in /Users/bblais/venvs/work/lib/python3.12/site-packages (from classy==0.0.71) (0.7.2)
# Requirement already satisfied: msgpack in /Users/bblais/venvs/work/lib/python3.12/site-packages (from flax->classy==0.0.71) (1.1.2)
# Requirement already satisfied: optax in /Users/bblais/venvs/work/lib/python3.12/site-packages (from flax->classy==0.0.71) (0.2.8)
# Requirement already satisfied: orbax-checkpoint in /Users/bblais/venvs/work/lib/python3.12/site-packages (from flax->classy==0.0.71) (0.11.36)
# Requirement already satisfied: tensorstore in /Users/bblais/venvs/work/lib/python3.12/site-packages (from flax->classy==0.0.71) (0.1.82)
# Requirement already satisfied: rich>=11.1 in /Users/bblais/venvs/work/lib/python3.12/site-packages (from flax->classy==0.0.71) (13.9.4)
# Requirement already satisfied: typing_extensions>=4.2 in /Users/bblais/venvs/work/lib/python3.12/site-packages (from flax->classy==0.0.71) (4.15.0)
# Requirement already satisfied: PyYAML>=5.4.1 in /Users/bblais/venvs/work/lib/python3.12/site-packages (from flax->classy==0.0.71) (6.0.3)
# Requirement already satisfied: treescope>=0.1.7 in /Users/bblais/venvs/work/lib/python3.12/site-packages (from flax->classy==0.0.71) (0.1.10)
# Requirement already satisfied: jaxlib<=0.7.2,>=0.7.2 in /Users/bblais/venvs/work/lib/python3.12/site-packages (from jax->classy==0.0.71) (0.7.2)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /Users/bblais/venvs/work/lib/python3.12/site-packages (from jax->classy==0.0.71) (0.5.4)
# Requirement already satisfied: opt_einsum in /Users/bblais/venvs/work/lib/python3.12/site-packages (from jax->classy==0.0.71) (3.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/bblais/venvs/work/lib/python3.12/site-packages (from rich>=11.1->flax->classy==0.0.71) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/bblais/venvs/work/lib/python3.12/site-packages (from rich>=11.1->flax->classy==0.0.71) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/bblais/venvs/work/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax->classy==0.0.71) (0.1.2)
# Requirement already satisfied: absl-py>=0.7.1 in /Users/bblais/venvs/work/lib/python3.12/site-packages (from optax->flax->classy==0.0.71) (2.4.0)
# Requirement already satisfied: etils[epath,epy] in /Users/bblais/venvs/work/lib/python3.12/site-packages (from orbax-checkpoint->flax->classy==0.0.71) (1.14.0)
# Requirement already satisfied: aiofiles in /Users/bblais/venvs/work/lib/python3.12/site-packages (from orbax-checkpoint->flax->classy==0.0.71) (25.1.0)
# Requirement already satisfied: protobuf in /Users/bblais/venvs/work/lib/python3.12/site-packages (from orbax-checkpoint->flax->classy==0.0.71) (7.34.1)
# Requirement already satisfied: humanize in /Users/bblais/venvs/work/lib/python3.12/site-packages (from orbax-checkpoint->flax->classy==0.0.71) (4.15.0)
# Requirement already satisfied: simplejson>=3.16.0 in /Users/bblais/venvs/work/lib/python3.12/site-packages (from orbax-checkpoint->flax->classy==0.0.71) (4.1.1)
# Requirement already satisfied: psutil in /Users/bblais/venvs/work/lib/python3.12/site-packages (from orbax-checkpoint->flax->classy==0.0.71) (7.2.2)
# Requirement already satisfied: uvloop in /Users/bblais/venvs/work/lib/python3.12/site-packages (from orbax-checkpoint->flax->classy==0.0.71) (0.22.1)
# Requirement already satisfied: fsspec in /Users/bblais/venvs/work/lib/python3.12/site-packages (from etils[epath,epy]->orbax-checkpoint->flax->classy==0.0.71) (2026.3.0)
# Requirement already satisfied: zipp in /Users/bblais/venvs/work/lib/python3.12/site-packages (from etils[epath,epy]->orbax-checkpoint->flax->classy==0.0.71) (3.23.1)
# Building wheels for collected packages: classy
#   Building wheel for classy (pyproject.toml) ... done
#   Created wheel for classy: filename=classy-0.0.71-py3-none-any.whl size=49350 sha256=58d0b40320ad546910c162b51c8ddcf3e9e78c6271c0653088742e6f090e6a70
#   Stored in directory: /Users/bblais/tmp/pip-ephem-wheel-cache-euwhve3a/wheels/ce/f3/ac/9512eb6f7a10ea1054138d71d7b96fbaa03c390fd2dd08e85a
# Successfully built classy
# Installing collected packages: classy
# Successfully installed classy-0.0.71

# %%
# !pip install "git+https://github.com/bblais/NumpyNet" --upgrade
# Out:
# Collecting git+https://github.com/bblais/NumpyNet
#   Cloning https://github.com/bblais/NumpyNet to /Users/bblais/tmp/pip-req-build-ub6tf_2p
#   Running command git clone -q https://github.com/bblais/NumpyNet /Users/bblais/tmp/pip-req-build-ub6tf_2p
# Collecting opencv-python<=4.1.2.30
#   Downloading opencv_python-4.1.2.30-cp38-cp38-macosx_10_9_x86_64.whl (45.2 MB)
#      |████████████████████████████████| 45.2 MB 2.9 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.15 in /Users/bblais/opt/anaconda3/lib/python3.8/site-packages (from NumPyNet==1.0.6) (1.20.1)
# Requirement already satisfied: pillow in /Users/bblais/opt/anaconda3/lib/python3.8/site-packages (from NumPyNet==1.0.6) (8.2.0)
# Requirement already satisfied: pytest in /Users/bblais/opt/anaconda3/lib/python3.8/site-packages (from NumPyNet==1.0.6) (6.2.3)
# Collecting enum34
#   Downloading enum34-1.1.10-py3-none-any.whl (11 kB)
# Collecting configparser
#   Downloading configparser-5.1.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: tqdm in /Users/bblais/opt/anaconda3/lib/python3.8/site-packages (from NumPyNet==1.0.6) (4.59.0)
# Requirement already satisfied: attrs>=19.2.0 in /Users/bblais/opt/anaconda3/lib/python3.8/site-packages (from pytest->NumPyNet==1.0.6) (20.3.0)
# Requirement already satisfied: iniconfig in /Users/bblais/opt/anaconda3/lib/python3.8/site-packages (from pytest->NumPyNet==1.0.6) (1.1.1)
# Requirement already satisfied: packaging in /Users/bblais/opt/anaconda3/lib/python3.8/site-packages (from pytest->NumPyNet==1.0.6) (20.9)
# Requirement already satisfied: pluggy<1.0.0a1,>=0.12 in /Users/bblais/opt/anaconda3/lib/python3.8/site-packages (from pytest->NumPyNet==1.0.6) (0.13.1)
# Requirement already satisfied: py>=1.8.2 in /Users/bblais/opt/anaconda3/lib/python3.8/site-packages (from pytest->NumPyNet==1.0.6) (1.10.0)
# Requirement already satisfied: toml in /Users/bblais/opt/anaconda3/lib/python3.8/site-packages (from pytest->NumPyNet==1.0.6) (0.10.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/bblais/opt/anaconda3/lib/python3.8/site-packages (from packaging->pytest->NumPyNet==1.0.6) (2.4.7)
# Building wheels for collected packages: NumPyNet
#   Building wheel for NumPyNet (setup.py) ... done
#   Created wheel for NumPyNet: filename=NumPyNet-1.0.6-py3-none-any.whl size=95884 sha256=421a84b9f9333490873456ad48b95ffef3057e2ac1041f92f1fa81ae00f8c2d2
#   Stored in directory: /Users/bblais/tmp/pip-ephem-wheel-cache-ki6dlpdl/wheels/65/35/4f/b2983231593896658f79cbc5028a95d48579d3ee64a16f2ed2
# Successfully built NumPyNet
# Installing collected packages: opencv-python, enum34, configparser, NumPyNet
# Successfully installed NumPyNet-1.0.6 configparser-5.1.0 enum34-1.1.10 opencv-python-4.1.2.30

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /Users/bblais/opt/anaconda3/envs/py3/lib/python3.7/site-packages (4.50.0)

# %% [markdown]
# this one is for cv2

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /Users/bblais/opt/anaconda3/lib/python3.9/site-packages (3.4.18.65)
# Requirement already satisfied: numpy>=1.14.5 in /Users/bblais/opt/anaconda3/lib/python3.9/site-packages (from opencv-python) (1.21.5)
